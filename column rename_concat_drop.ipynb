# %% [markdown]
# # Grouping and aggregation

# %%
from os import chdir

# %%
chdir("C:/Users/Suja4/OneDrive/Documents/Data Science/Dataset")

# %%
import pandas as pd

# %%
A=pd.read_csv('cars93.csv')

# %%
A.Weight.sum()
# Out:
# 285780

# %%
A.Weight.max()
# Out:
# 4105

# %%
A.Weight.min()
# Out:
# 1695

# %%
A.Weight.mean()
# Out:
# 3072.9032258064517

# %%
round(A.Weight.mean(),3)
# Out:
# 3072.903

# %%
A.Weight.count()
# Out:
# 93

# %%
A.groupby(by=['Type'])['Price'].min()
# Out:
# Type
# Compact    11.1
# Large      18.4
# Midsize    13.9
# Small       7.4
# Sporty     10.0
# Van        16.3
# Name: Price, dtype: float64

# %%
Q=[]

# %%
A
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
A['MPG.city']
# Out:
# 0     25
# 1     18
# 2     20
# 3     19
# 4     22
#       ..
# 88    17
# 89    21
# 90    18
# 91    21
# 92    20
# Name: MPG.city, Length: 93, dtype: int64

# %%
for i in A['MPG.city']:
    if( i>15 and i<25):
        Q.append("Low")
    elif(i>25 and i<=35):
        Q.append("Moderate")
    else:
        Q.append("High")

# %%
Q
# Out:
# ['High',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'High',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Moderate',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Moderate',
#  'Low',
#  'Moderate',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'High',
#  'Moderate',
#  'Low',
#  'High',
#  'Low',
#  'Moderate',
#  'Low',
#  'Moderate',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Moderate',
#  'Low',
#  'Moderate',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Moderate',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Low',
#  'Moderate',
#  'Moderate',
#  'High',
#  'Low',
#  'High',
#  'Moderate',
#  'High',
#  'Low',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'Low',
# ...

# %%
A['Milege Type']=Q

# %%
A.head(3)
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
#
#    MPG.highway             AirBags  ... Length Wheelbase  Width  Turn.circle  \
# 0           31                None  ...    177       102     68           37
# 1           25  Driver & Passenger  ...    195       115     71           38
# 2           26         Driver only  ...    180       102     67           37
#
#    Rear.seat.room  Luggage.room Weight   Origin           Make  Milege Type
# 0            26.5          11.0   2705  non-USA  Acura Integra         High
# 1            30.0          15.0   3560  non-USA   Acura Legend          Low
# 2            28.0          14.0   3375  non-USA        Audi 90          Low
#
# [3 rows x 29 columns]

# %%
A1=A[0:10]

# %%
A2=A[10:20]

# %%
pd.concat([A1,A2])
# Out:
#     id Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 0    1        Acura     Integra    Small       12.9   15.9       18.8
# 1    2        Acura      Legend  Midsize       29.2   33.9       38.7
# 2    3         Audi          90  Compact       25.9   29.1       32.3
# 3    4         Audi         100  Midsize       30.8   37.7       44.6
# 4    5          BMW        535i  Midsize       23.7   30.0       36.2
# 5    6        Buick     Century  Midsize       14.2   15.7       17.3
# 6    7        Buick     LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick  Roadmaster    Large       22.6   23.7       24.9
# 8    9        Buick     Riviera  Midsize       26.3   26.3       26.3
# 9   10     Cadillac     DeVille    Large       33.0   34.7       36.3
# 10  11     Cadillac     Seville  Midsize       37.5   40.1       42.7
# 11  12    Chevrolet    Cavalier  Compact        8.5   13.4       18.3
# ...

# %%
A3=A1.append(A2)
# Out:
# C:\Users\Suja4\AppData\Local\Temp\ipykernel_20576\2890856480.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   A3=A1.append(A2)

# %%
A3
# Out:
#     id Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 0    1        Acura     Integra    Small       12.9   15.9       18.8
# 1    2        Acura      Legend  Midsize       29.2   33.9       38.7
# 2    3         Audi          90  Compact       25.9   29.1       32.3
# 3    4         Audi         100  Midsize       30.8   37.7       44.6
# 4    5          BMW        535i  Midsize       23.7   30.0       36.2
# 5    6        Buick     Century  Midsize       14.2   15.7       17.3
# 6    7        Buick     LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick  Roadmaster    Large       22.6   23.7       24.9
# 8    9        Buick     Riviera  Midsize       26.3   26.3       26.3
# 9   10     Cadillac     DeVille    Large       33.0   34.7       36.3
# 10  11     Cadillac     Seville  Midsize       37.5   40.1       42.7
# 11  12    Chevrolet    Cavalier  Compact        8.5   13.4       18.3
# ...

# %% [markdown]
# # drop columns and rows

# %%
A.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make', 'Milege Type'],
#       dtype='object')

# %% [markdown]
# #axis1 --> columns
# #axis0 --> rows

# %%
A.drop(labels=["Manufacturer"],axis=1)
# Out:
#     id    Model     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0    1  Integra    Small       12.9   15.9       18.8        25           31
# 1    2   Legend  Midsize       29.2   33.9       38.7        18           25
# 2    3       90  Compact       25.9   29.1       32.3        20           26
# 3    4      100  Midsize       30.8   37.7       44.6        19           26
# 4    5     535i  Midsize       23.7   30.0       36.2        22           30
# ..  ..      ...      ...        ...    ...        ...       ...          ...
# 88  89  Eurovan      Van       16.6   19.7       22.7        17           21
# 89  90   Passat  Compact       17.6   20.0       22.4        21           30
# 90  91  Corrado   Sporty       22.9   23.3       23.7        18           25
# 91  92      240  Compact       21.8   22.7       23.5        21           28
# 92  93      850  Midsize       24.8   26.7       28.5        20           28
#
# ...

# %%
A.drop(index=[2,4],axis=0)
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 5    6        Buick  Century  Midsize       14.2   15.7       17.3        22
# 6    7        Buick  LeSabre    Large       19.9   20.8       21.7        19
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
A.shape
# Out:
# (93, 29)

# %%
A.index=range(0,A.shape[0],1)

# %%
A
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
A=A.rename(mapper={"EngineSize":"ES"},axis=1)

# %%
A
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...
