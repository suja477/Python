# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd
A=pd.read_csv("/Users/Suja4/OneDrive/Documents/Data Science/Dataset/Cars93.csv")

A
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
B=A[["Type","Weight"]]
B
# Out:
#        Type  Weight
# 0     Small    2705
# 1   Midsize    3560
# 2   Compact    3375
# 3   Midsize    3405
# 4   Midsize    3640
# ..      ...     ...
# 88      Van    3960
# 89  Compact    2985
# 90   Sporty    2810
# 91  Compact    2985
# 92  Midsize    3245
#
# [93 rows x 2 columns]

# %%
C=B.sort_values(by=["Type","Weight"])
C
# Out:
#        Type  Weight
# 11  Compact    2490
# 73  Compact    2575
# 32  Compact    2690
# 77  Compact    2775
# 12  Compact    2785
# ..      ...     ...
# 55      Van    3735
# 86      Van    3785
# 88      Van    3960
# 16      Van    4025
# 65      Van    4100
#
# [93 rows x 2 columns]

# %%
import seaborn as sb
sb.boxplot(C.Type,C.Weight)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Weight'>

# %%
sb.boxplot(C.Type,C.Weight,order=["Small","Sporty","Compact","Midsize","Large","Van"])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Weight'>

# %% [markdown]
# # countplot with hue

# %%
A.AirBags=A.AirBags.fillna("No Driver")

# %%
A
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
B= A[["Type","AirBags"]]

C = B.sort_values(by=["Type","AirBags"])
C
# Out:
#        Type             AirBags
# 20  Compact  Driver & Passenger
# 42  Compact  Driver & Passenger
# 2   Compact         Driver only
# 12  Compact         Driver only
# 24  Compact         Driver only
# ..      ...                 ...
# 16      Van                None
# 55      Van                None
# 65      Van                None
# 69      Van                None
# 88      Van                None
#
# [93 rows x 2 columns]

# %%
sb.countplot(B.Type)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sb.countplot(B.Type,hue=B.AirBags)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
pd.crosstab(A.Type,A.AirBags)
# Out:
# AirBags  Driver & Passenger  Driver only  No Driver  None
# Type
# Compact                   2            9          0     5
# Large                     3            6          2     0
# Midsize                   6           11          1     4
# Small                     0            5          0    16
# Sporty                    3            8          1     2
# Van                       0            3          0     6

# %%
A[A.Type=="Small"].groupby(by="AirBags")["id"].count()
# Out:
# AirBags
# Driver only     5
# None           16
# Name: id, dtype: int64
